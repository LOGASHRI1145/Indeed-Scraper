# %%
# !pip install apify_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.2 MB/s eta 0:00:00
# ...

# %%
from apify_client import ApifyClient

# Initialize the ApifyClient with your API token
client = ApifyClient("apify_api_gnHNn1Rfrdpp2Ac9kRfygdIrK8LpZS2LEeyy")

# Prepare the Actor input
run_input = {
    "position": "web developer",
    "country": "US",
    "location": "San Francisco",
    "maxItems": 20,
    "parseCompanyDetails": False,
    "saveOnlyUniqueItems": True,
    "followApplyRedirects": False,
}

# Run the Actor and wait for it to finish
run = client.actor("hMvNSpz3JnHgl5jkh").call(run_input=run_input)

# Fetch and print Actor results from the run's dataset (if there are any)
for item in client.dataset(run["defaultDatasetId"]).iterate_items():
  print(item)
# Out:
# {'positionName': 'FullStack Software Engineer - FE & BE ( React / Python )', 'salary': '$110,000 - $142,000 a year', 'jobType': None, 'company': 'Eightfold.AI', 'location': 'Santa Clara, CA', 'rating': 1, 'reviewsCount': 2, 'urlInput': None, 'url': 'https://www.indeed.com/viewjob?jk=6e504fd059cd71ee&vjs=3', 'id': '6e504fd059cd71ee', 'postedAt': 'Just posted', 'scrapedAt': '2024-10-25T15:56:49.686Z', 'postingDateParsed': '2024-10-25T15:56:49.684Z', 'description': "About the Team \n \n \n  The Talent Management (TM) product team at Eightfold.AI builds new product experiences for Eightfold customers and users. Our AI-driven TM products will be used by millions of Users to leverage AI to help them learn & grow in their career. It will innovate how every person can manage every step of their career journey.\n \n \n  We are building best-in-class consumer-facing products that cover a vast variety of user journeys ranging from employee retention, career pathing, mentorship, enrichment, lear
# ...

# %%
import pandas as pd
from google.colab import files

# Initialize an empty list to store job data
job_listings = []

# Fetch and store Actor results from the run's dataset
for item in client.dataset(run["defaultDatasetId"]).iterate_items():
    job_listings.append(item)

# Create a pandas DataFrame from the job listings
df = pd.DataFrame(job_listings)

# Save the DataFrame to a CSV file in Google Colab
df.to_csv('job_listings.csv', index=False)

# Download the file to your local machine
files.download('job_listings.csv')

print("Job listings have been saved and downloaded as 'job_listings.csv'")
# Out:
# Job listings have been saved and downloaded as 'job_listings.csv'
